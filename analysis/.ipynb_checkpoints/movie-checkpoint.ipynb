# %%
# %matplotlib inline
import pandas as pd
# Out:
# /Users/sean/.pyenv/versions/movie-data/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
movies = pd.read_csv('movies.csv')

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 电影与分差的分布

# %%
diff = movies['diff']
diff.mean()
# movies['movie_year'].hist(bins=100)
# movies.plot(style='k', x='diff', y='movie_year')
plt.scatter(movies['diff'], movies['movie_year'], s=5)

# %% [markdown]
# ## Diff

# %%
diff.hist(bins=60)
